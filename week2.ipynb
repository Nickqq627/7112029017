# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickqq627/7112029017/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 引入requests庫
import requests
# 定義API的URL
url = 'https://openapi.twse.com.tw/v1/exchangeReport/STOCK_DAY_ALL'
# 發送GET請求
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
import json

jsondata = json.loads(res.text)
jsondata
# Out:
# [{'Code': '0050',
#   'Name': '元大台灣50',
#   'TradeVolume': '8553792',
#   'TradeValue': '1532937205',
#   'OpeningPrice': '178.00',
#   'HighestPrice': '180.20',
#   'LowestPrice': '177.00',
#   'ClosingPrice': '180.15',
#   'Change': '2.3000',
#   'Transaction': '10740'},
#  {'Code': '0051',
#   'Name': '元大中型100',
#   'TradeVolume': '54240',
#   'TradeValue': '4334120',
#   'OpeningPrice': '79.05',
#   'HighestPrice': '80.60',
#   'LowestPrice': '79.05',
#   'ClosingPrice': '80.60',
#   'Change': '1.3500',
#   'Transaction': '203'},
#  {'Code': '0052',
#   'Name': '富邦科技',
#   'TradeVolume': '340371',
#   'TradeValue': '59429145',
#   'OpeningPrice': '172.85',
#   'HighestPrice': '175.95',
#   'LowestPrice': '172.50',
#   'ClosingPrice': '175.95',
#   'Change': '2.7500',
#   'Transaction': '854'},
#  {'Code': '0053',
#   'Name': '元大電子',
#   'TradeVolume': '6900',
#   'TradeValue': '660155',
#   'OpeningPrice': '95.45',
#   'HighestPrice': '96.45',
#   'LowestPrice': '95.00',
#   'ClosingPrice': '96.45',
#   'Change': '1.6000',
#   'Transaction': '108'},
#  {'Code': '0055',
#   'Name': '元大MSCI金融',
#   'TradeVolume': '122249',
#   'TradeValue': '3532429',
#   'OpeningPrice': '28.65',
#   'HighestPrice': '28.99',
#   'LowestPrice': '28.62',
#   'ClosingPrice': '28.99',
#   'Change': '0.3800',
#   'Transaction': '246'},
#  {'Code': '0056',
#   'Name': '元大高股息',
#   'TradeVolume': '13618023',
#   'TradeValue': '515608458',
#   'OpeningPrice': '37.72',
#   'HighestPrice': '38.07',
#   'LowestPrice': '37.62',
#   'ClosingPrice': '37.97',
#   'Change': '0.2500',
#   'Transaction': '10020'},
#  {'Code': '0057',
#   'Name': '富邦摩台',
#   'TradeVolume': '15269',
#   'TradeValue': '2021284',
#   'OpeningPrice': '131.30',
#   'HighestPrice': '132.90',
#   'LowestPrice': '131.30',
#   'ClosingPrice': '132.90',
#   'Change': '2.0000',
#   'Transaction': '83'},
#  {'Code': '0061',
#   'Name': '元大寶滬深',
#   'TradeVolume': '165146',
#   'TradeValue': '2663828',
#   'OpeningPrice': '15.97',
#   'HighestPrice': '16.22',
#   'LowestPrice': '15.95',
#   'ClosingPrice': '16.20',
#   'Change': '0.2300',
#   'Transaction': '129'},
#  {'Code': '006203',
#   'Name': '元大MSCI台灣',
#   'TradeVolume': '4615',
#   'TradeValue': '389204',
#   'OpeningPrice': '84.20',
#   'HighestPrice': '85.05',
#   'LowestPrice': '84.20',
#   'ClosingPrice': '85.05',
#   'Change': '0.9000',
#   'Transaction': '111'},
#  {'Code': '006204',
#   'Name': '永豐臺灣加權',
#   'TradeVolume': '23409',
#   'TradeValue': '2576601',
#   'OpeningPrice': '108.95',
#   'HighestPrice': '110.30',
#   'LowestPrice': '108.95',
#   'ClosingPrice': '110.30',
#   'Change': '0.8500',
#   'Transaction': '115'},
#  {'Code': '006205',
#   'Name': '富邦上証',
#   'TradeVolume': '1608275',
#   'TradeValue': '44585230',
#   'OpeningPrice': '27.60',
#   'HighestPrice': '28.02',
#   'LowestPrice': '27.50',
#   'ClosingPrice': '27.99',
#   'Change': '0.5100',
#   'Transaction': '271'},
#  {'Code': '006206',
#   'Name': '元大上證50',
#   'TradeVolume': '70557',
#   'TradeValue': '1888249',
#   'OpeningPrice': '26.70',
#   'HighestPrice': '27.10',
#   'LowestPrice': '26.45',
#   'ClosingPrice': '26.93',
#   'Change': '0.4800',
#   'Transaction': '102'},
#  {'Code': '006207',
#   'Name': '復華滬深',
#   'TradeVolume': '75390',
#   'TradeValue': '1562886',
#   'OpeningPrice': '20.50',
#   'HighestPrice': '20.80',
#   'LowestPrice': '20.42',
#   'ClosingPrice': '20.77',
#   'Change': '0.3500',
#   'Transaction': '69'},
#  {'Code': '006208',
#   'Name': '富邦台50',
#   'TradeVolume': '4790945',
#   'TradeValue': '501060481',
#   'OpeningPrice': '103.90',
#   'HighestPrice': '105.35',
#   'LowestPrice': '103.60',
#   'ClosingPrice': '105.35',
#   'Change': '1.4500',
#   'Transaction': '7295'},
#  {'Code': '00625K',
#   'Name': '富邦上証+R',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '00631L',
#   'Name': '元大台灣50正2',
#   'TradeVolume': '5586224',
#   'TradeValue': '1230128002',
#   'OpeningPrice': '217.05',
#   'HighestPrice': '223.75',
#   'LowestPrice': '215.75',
#   'ClosingPrice': '223.35',
#   'Change': '7.3000',
#   'Transaction': '4736'},
#  {'Code': '00632R',
#   'Name': '元大台灣50反1',
#   'TradeVolume': '278182260',
#   'TradeValue': '964942710',
#   'OpeningPrice': '3.50',
#   'HighestPrice': '3.52',
#   'LowestPrice': '3.44',
#   'ClosingPrice': '3.44',
#   'Change': '-0.0700',
#   'Transaction': '9298'},
#  {'Code': '00633L',
#   'Name': '富邦上証正2',
#   'TradeVolume': '7178541',
#   'TradeValue': '207346012',
#   'OpeningPrice': '28.80',
#   'HighestPrice': '29.41',
#   'LowestPrice': '28.30',
#   'ClosingPrice': '29.27',
#   'Change': '0.6100',
#   'Transaction': '1754'},
#  {'Code': '00634R',
#   'Name': '富邦上証反1',
#   'TradeVolume': '1132200',
#   'TradeValue': '5592914',
#   'OpeningPrice': '4.94',
#   'HighestPrice': '4.99',
#   'LowestPrice': '4.89',
#   'ClosingPrice': '4.91',
#   'Change': '-0.0400',
#   'Transaction': '48'},
#  {'Code': '00635U',
#   'Name': '期元大S&P黃金',
#   'TradeVolume': '853763',
#   'TradeValue': '25356343',
#   'OpeningPrice': '29.62',
#   'HighestPrice': '29.80',
#   'LowestPrice': '29.58',
#   'ClosingPrice': '29.80',
#   'Change': '0.0400',
#   'Transaction': '502'},
#  {'Code': '00636',
#   'Name': '國泰中國A50',
#   'TradeVolume': '1962534',
#   'TradeValue': '38182681',
#   'OpeningPrice': '19.34',
#   'HighestPrice': '19.65',
#   'LowestPrice': '19.23',
#   'ClosingPrice': '19.61',
#   'Change': '0.3400',
#   'Transaction': '272'},
#  {'Code': '00636K',
#   'Name': '國泰中國A50+U',
#   'TradeVolume': '200',
#   'TradeValue': '1222',
#   'OpeningPrice': '6.11',
#   'HighestPrice': '6.11',
#   'LowestPrice': '6.11',
#   'ClosingPrice': '6.11',
#   'Change': '0.0500',
#   'Transaction': '2'},
#  {'Code': '00637L',
#   'Name': '元大滬深300正2',
#   'TradeVolume': '85162950',
#   'TradeValue': '985747817',
#   'OpeningPrice': '11.58',
#   'HighestPrice': '11.78',
#   'LowestPrice': '11.33',
#   'ClosingPrice': '11.73',
#   'Change': '0.2600',
#   'Transaction': '7614'},
#  {'Code': '00638R',
#   'Name': '元大滬深300反1',
#   'TradeVolume': '744613',
#   'TradeValue': '7655767',
#   'OpeningPrice': '10.38',
#   'HighestPrice': '10.43',
#   'LowestPrice': '10.22',
#   'ClosingPrice': '10.24',
#   'Change': '-0.1200',
#   'Transaction': '44'},
#  {'Code': '00639',
#   'Name': '富邦深100',
#   'TradeVolume': '1622571',
#   'TradeValue': '15319634',
#   'OpeningPrice': '9.33',
#   'HighestPrice': '9.55',
#   'LowestPrice': '9.31',
#   'ClosingPrice': '9.50',
#   'Change': '0.2300',
#   'Transaction': '253'},
#  {'Code': '00640L',
#   'Name': '富邦日本正2',
#   'TradeVolume': '1807791',
#   'TradeValue': '87852150',
#   'OpeningPrice': '47.97',
#   'HighestPrice': '48.93',
#   'LowestPrice': '47.97',
#   'ClosingPrice': '48.72',
#   'Change': '2.5400',
#   'Transaction': '794'},
#  {'Code': '00641R',
#   'Name': '富邦日本反1',
#   'TradeVolume': '3218094',
#   'TradeValue': '20743275',
#   'OpeningPrice': '6.48',
#   'HighestPrice': '6.48',
#   'LowestPrice': '6.42',
#   'ClosingPrice': '6.42',
#   'Change': '-0.2000',
#   'Transaction': '320'},
#  {'Code': '00642U',
#   'Name': '期元大S&P石油',
#   'TradeVolume': '5093897',
#   'TradeValue': '82491519',
#   'OpeningPrice': '16.17',
#   'HighestPrice': '16.28',
#   'LowestPrice': '16.09',
#   'ClosingPrice': '16.25',
#   'Change': '0.0900',
#   'Transaction': '1158'},
#  {'Code': '00643',
#   'Name': '群益深証中小',
#   'TradeVolume': '1322888',
#   'TradeValue': '13942535',
#   'OpeningPrice': '10.48',
#   'HighestPrice': '10.66',
#   'LowestPrice': '10.40',
#   'ClosingPrice': '10.58',
#   'Change': '0.2200',
#   'Transaction': '148'},
#  {'Code': '00643K',
#   'Name': '群益深証中小+R',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '00645',
#   'Name': '富邦日本',
#   'TradeVolume': '508134',
#   'TradeValue': '18208181',
#   'OpeningPrice': '35.69',
#   'HighestPrice': '35.94',
#   'LowestPrice': '35.68',
#   'ClosingPrice': '35.81',
#   'Change': '0.9200',
#   'Transaction': '282'},
#  {'Code': '00646',
#   'Name': '元大S&P500',
#   'TradeVolume': '2811199',
#   'TradeValue': '159175923',
#   'OpeningPrice': '56.30',
#   'HighestPrice': '56.80',
#   'LowestPrice': '56.30',
#   'ClosingPrice': '56.65',
#   'Change': '0.3500',
#   'Transaction': '831'},
#  {'Code': '00647L',
#   'Name': '元大S&P500正2',
#   'TradeVolume': '217414',
#   'TradeValue': '19953351',
#   'OpeningPrice': '91.60',
#   'HighestPrice': '92.50',
#   'LowestPrice': '91.50',
#   'ClosingPrice': '92.30',
#   'Change': '0.9000',
#   'Transaction': '109'},
#  {'Code': '00648R',
#   'Name': '元大S&P500反1',
#   'TradeVolume': '1079446',
#   'TradeValue': '5786388',
#   'OpeningPrice': '5.38',
#   'HighestPrice': '5.38',
#   'LowestPrice': '5.34',
#   'ClosingPrice': '5.35',
#   'Change': '-0.0400',
#   'Transaction': '133'},
#  {'Code': '00650L',
#   'Name': '復華香港正2',
#   'TradeVolume': '25023207',
#   'TradeValue': '251869214',
#   'OpeningPrice': '9.88',
#   'HighestPrice': '10.29',
#   'LowestPrice': '9.79',
#   'ClosingPrice': '10.22',
#   'Change': '0.5300',
#   'Transaction': '2657'},
#  {'Code': '00651R',
#   'Name': '復華香港反1',
#   'TradeVolume': '921100',
#   'TradeValue': '7914598',
#   'OpeningPrice': '8.78',
#   'HighestPrice': '8.78',
#   'LowestPrice': '8.51',
#   'ClosingPrice': '8.55',
#   'Change': '-0.2200',
#   'Transaction': '149'},
#  {'Code': '00652',
#   'Name': '富邦印度',
#   'TradeVolume': '248018',
#   'TradeValue': '10060570',
#   'OpeningPrice': '40.43',
#   'HighestPrice': '40.78',
#   'LowestPrice': '40.42',
#   'ClosingPrice': '40.65',
#   'Change': '0.3400',
#   'Transaction': '224'},
#  {'Code': '00653L',
#   'Name': '富邦印度正2',
#   'TradeVolume': '198391',
#   'TradeValue': '13617751',
#   'OpeningPrice': '68.15',
#   'HighestPrice': '69.35',
#   'LowestPrice': '67.95',
#   'ClosingPrice': '68.85',
#   'Change': '0.3500',
#   'Transaction': '104'},
#  {'Code': '00654R',
#   'Name': '富邦印度反1',
#   'TradeVolume': '776000',
#   'TradeValue': '4740360',
#   'OpeningPrice': '6.15',
#   'HighestPrice': '6.15',
#   'LowestPrice': '6.08',
#   'ClosingPrice': '6.08',
#   'Change': '-0.0400',
#   'Transaction': '87'},
#  {'Code': '00655L',
#   'Name': '國泰中國A50正2',
#   'TradeVolume': '5592160',
#   'TradeValue': '110040033',
#   'OpeningPrice': '19.58',
#   'HighestPrice': '20.02',
#   'LowestPrice': '19.25',
#   'ClosingPrice': '19.93',
#   'Change': '0.4200',
#   'Transaction': '810'},
#  {'Code': '00656R',
#   'Name': '國泰中國A50反1',
#   'TradeVolume': '962000',
#   'TradeValue': '8905630',
#   'OpeningPrice': '9.28',
#   'HighestPrice': '9.36',
#   'LowestPrice': '9.19',
#   'ClosingPrice': '9.21',
#   'Change': '-0.1100',
#   'Transaction': '26'},
#  {'Code': '00657',
#   'Name': '國泰日經225',
#   'TradeVolume': '149418',
#   'TradeValue': '6549578',
#   'OpeningPrice': '43.67',
#   'HighestPrice': '43.96',
#   'LowestPrice': '43.67',
#   'ClosingPrice': '43.83',
#   'Change': '1.1100',
#   'Transaction': '146'},
#  {'Code': '00657K',
#   'Name': '國泰日經225+U',
#   'TradeVolume': '200',
#   'TradeValue': '2740',
#   'OpeningPrice': '13.70',
#   'HighestPrice': '13.70',
#   'LowestPrice': '13.70',
#   'ClosingPrice': '13.70',
#   'Change': '0.3700',
#   'Transaction': '2'},
#  {'Code': '00660',
#   'Name': '元大歐洲50',
#   'TradeVolume': '8901',
#   'TradeValue': '317247',
#   'OpeningPrice': '35.65',
#   'HighestPrice': '35.69',
#   'LowestPrice': '35.65',
#   'ClosingPrice': '35.69',
#   'Change': '0.1800',
#   'Transaction': '70'},
#  {'Code': '00661',
#   'Name': '元大日經225',
#   'TradeVolume': '865709',
#   'TradeValue': '41303906',
#   'OpeningPrice': '47.49',
#   'HighestPrice': '47.90',
#   'LowestPrice': '47.43',
#   'ClosingPrice': '47.73',
#   'Change': '1.1000',
#   'Transaction': '230'},
#  {'Code': '00662',
#   'Name': '富邦NASDAQ',
#   'TradeVolume': '2533667',
#   'TradeValue': '204595211',
#   'OpeningPrice': '80.00',
#   'HighestPrice': '80.95',
#   'LowestPrice': '80.00',
#   'ClosingPrice': '80.80',
#   'Change': '0.8500',
#   'Transaction': '725'},
#  {'Code': '00663L',
#   'Name': '國泰臺灣加權正2',
#   'TradeVolume': '17153',
#   'TradeValue': '3441021',
#   'OpeningPrice': '198.60',
#   'HighestPrice': '204.45',
#   'LowestPrice': '197.80',
#   'ClosingPrice': '204.45',
#   'Change': '6.7500',
#   'Transaction': '19'},
#  {'Code': '00664R',
#   'Name': '國泰臺灣加權反1',
#   'TradeVolume': '14830427',
#   'TradeValue': '57909454',
#   'OpeningPrice': '3.95',
#   'HighestPrice': '3.96',
#   'LowestPrice': '3.88',
#   'ClosingPrice': '3.88',
#   'Change': '-0.0800',
#   'Transaction': '818'},
#  {'Code': '00665L',
#   'Name': '富邦恒生國企正2',
#   'TradeVolume': '71630931',
#   'TradeValue': '462363158',
#   'OpeningPrice': '6.29',
#   'HighestPrice': '6.63',
#   'LowestPrice': '6.27',
#   'ClosingPrice': '6.59',
#   'Change': '0.3500',
#   'Transaction': '4400'},
#  {'Code': '00666R',
#   'Name': '富邦恒生國企反1',
#   'TradeVolume': '43000',
#   'TradeValue': '623720',
#   'OpeningPrice': '14.67',
#   'HighestPrice': '14.67',
#   'LowestPrice': '14.40',
#   'ClosingPrice': '14.47',
#   'Change': '-0.3600',
#   'Transaction': '34'},
#  {'Code': '00668',
#   'Name': '國泰美國道瓊',
#   'TradeVolume': '73665',
#   'TradeValue': '3568209',
#   'OpeningPrice': '48.52',
#   'HighestPrice': '48.54',
#   'LowestPrice': '48.38',
#   'ClosingPrice': '48.52',
#   'Change': '0.1900',
#   'Transaction': '109'},
#  {'Code': '00668K',
#   'Name': '國泰美國道瓊+U',
#   'TradeVolume': '200',
#   'TradeValue': '3036',
#   'OpeningPrice': '15.18',
#   'HighestPrice': '15.18',
#   'LowestPrice': '15.18',
#   'ClosingPrice': '15.18',
#   'Change': '0.0500',
#   'Transaction': '2'},
#  {'Code': '00669R',
#   'Name': '國泰美國道瓊反1',
#   'TradeVolume': '2413200',
#   'TradeValue': '16233171',
#   'OpeningPrice': '6.75',
#   'HighestPrice': '6.76',
#   'LowestPrice': '6.71',
#   'ClosingPrice': '6.72',
#   'Change': '-0.0200',
#   'Transaction': '241'},
#  {'Code': '00670L',
#   'Name': '富邦NASDAQ正2',
#   'TradeVolume': '1034671',
#   'TradeValue': '123688512',
#   'OpeningPrice': '118.60',
#   'HighestPrice': '120.50',
#   'LowestPrice': '118.25',
#   'ClosingPrice': '120.35',
#   'Change': '2.2500',
#   'Transaction': '614'},
#  {'Code': '00671R',
#   'Name': '富邦NASDAQ反1',
#   'TradeVolume': '6895065',
#   'TradeValue': '25975695',
#   'OpeningPrice': '3.79',
#   'HighestPrice': '3.80',
#   'LowestPrice': '3.75',
#   'ClosingPrice': '3.75',
#   'Change': '-0.0600',
#   'Transaction': '406'},
#  {'Code': '00673R',
#   'Name': '期元大S&P原油反1',
#   'TradeVolume': '13694563',
#   'TradeValue': '106267267',
#   'OpeningPrice': '7.77',
#   'HighestPrice': '7.82',
#   'LowestPrice': '7.71',
#   'ClosingPrice': '7.73',
#   'Change': '-0.0500',
#   'Transaction': '748'},
#  {'Code': '00674R',
#   'Name': '期元大S&P黃金反1',
#   'TradeVolume': '691922',
#   'TradeValue': '6796275',
#   'OpeningPrice': '9.84',
#   'HighestPrice': '9.85',
#   'LowestPrice': '9.79',
#   'ClosingPrice': '9.79',
#   'Change': '0.0000',
#   'Transaction': '119'},
#  {'Code': '00675L',
#   'Name': '富邦臺灣加權正2',
#   'TradeVolume': '3500190',
#   'TradeValue': '308377444',
#   'OpeningPrice': '86.90',
#   'HighestPrice': '89.50',
#   'LowestPrice': '86.30',
#   'ClosingPrice': '89.40',
#   'Change': '3.0000',
#   'Transaction': '2715'},
#  {'Code': '00676R',
#   'Name': '富邦臺灣加權反1',
#   'TradeVolume': '14080549',
#   'TradeValue': '30564875',
#   'OpeningPrice': '2.20',
#   'HighestPrice': '2.20',
#   'LowestPrice': '2.15',
#   'ClosingPrice': '2.16',
#   'Change': '-0.0400',
#   'Transaction': '518'},
#  {'Code': '00678',
#   'Name': '群益那斯達克生技',
#   'TradeVolume': '481539',
#   'TradeValue': '14987694',
#   'OpeningPrice': '30.96',
#   'HighestPrice': '31.18',
#   'LowestPrice': '30.96',
#   'ClosingPrice': '31.17',
#   'Change': '0.1400',
#   'Transaction': '99'},
#  {'Code': '00680L',
#   'Name': '元大美債20正2',
#   'TradeVolume': '193991879',
#   'TradeValue': '1885518317',
#   'OpeningPrice': '9.74',
#   'HighestPrice': '9.74',
#   'LowestPrice': '9.69',
#   'ClosingPrice': '9.73',
#   'Change': '-0.2800',
#   'Transaction': '15595'},
#  {'Code': '00681R',
#   'Name': '元大美債20反1',
#   'TradeVolume': '205000',
#   'TradeValue': '3877060',
#   'OpeningPrice': '18.90',
#   'HighestPrice': '18.95',
#   'LowestPrice': '18.90',
#   'ClosingPrice': '18.92',
#   'Change': '0.2400',
#   'Transaction': '40'},
#  {'Code': '00682U',
#   'Name': '期元大美元指數',
#   'TradeVolume': '7000',
#   'TradeValue': '143710',
#   'OpeningPrice': '20.55',
#   'HighestPrice': '20.55',
#   'LowestPrice': '20.48',
#   'ClosingPrice': '20.48',
#   'Change': '0.0700',
#   'Transaction': '3'},
#  {'Code': '00683L',
#   'Name': '期元大美元指正2',
#   'TradeVolume': '96500',
#   'TradeValue': '2075018',
#   'OpeningPrice': '21.60',
#   'HighestPrice': '21.60',
#   'LowestPrice': '21.37',
#   'ClosingPrice': '21.38',
#   'Change': '0.0700',
#   'Transaction': '17'},
#  {'Code': '00684R',
#   'Name': '期元大美元指反1',
#   'TradeVolume': '26000',
#   'TradeValue': '409610',
#   'OpeningPrice': '15.74',
#   'HighestPrice': '15.79',
#   'LowestPrice': '15.74',
#   'ClosingPrice': '15.79',
#   'Change': '-0.0400',
#   'Transaction': '9'},
#  {'Code': '00685L',
#   'Name': '群益臺灣加權正2',
#   'TradeVolume': '770418',
#   'TradeValue': '60260876',
#   'OpeningPrice': '77.50',
#   'HighestPrice': '79.85',
#   'LowestPrice': '76.90',
#   'ClosingPrice': '79.80',
#   'Change': '2.6500',
#   'Transaction': '460'},
#  {'Code': '00686R',
#   'Name': '群益臺灣加權反1',
#   'TradeVolume': '2613249',
#   'TradeValue': '6201917',
#   'OpeningPrice': '2.38',
#   'HighestPrice': '2.39',
#   'LowestPrice': '2.35',
#   'ClosingPrice': '2.35',
#   'Change': '-0.0300',
#   'Transaction': '71'},
#  {'Code': '00688L',
#   'Name': '國泰20年美債正2',
#   'TradeVolume': '94808001',
#   'TradeValue': '917900042',
#   'OpeningPrice': '9.67',
#   'HighestPrice': '9.70',
#   'LowestPrice': '9.65',
#   'ClosingPrice': '9.69',
#   'Change': '-0.2800',
#   'Transaction': '8551'},
#  {'Code': '00689R',
#   'Name': '國泰20年美債反1',
#   'TradeVolume': '4000',
#   'TradeValue': '78640',
#   'OpeningPrice': '19.66',
#   'HighestPrice': '19.66',
#   'LowestPrice': '19.66',
#   'ClosingPrice': '19.66',
#   'Change': '0.2900',
#   'Transaction': '2'},
#  {'Code': '00690',
#   'Name': '兆豐藍籌30',
#   'TradeVolume': '525956',
#   'TradeValue': '17499424',
#   'OpeningPrice': '32.84',
#   'HighestPrice': '33.38',
#   'LowestPrice': '32.84',
#   'ClosingPrice': '33.37',
#   'Change': '0.5400',
#   'Transaction': '296'},
#  {'Code': '00692',
#   'Name': '富邦公司治理',
#   'TradeVolume': '1486073',
#   'TradeValue': '62671224',
#   'OpeningPrice': '41.77',
#   'HighestPrice': '42.37',
#   'LowestPrice': '41.68',
#   'ClosingPrice': '42.33',
#   'Change': '0.5700',
#   'Transaction': '1305'},
#  {'Code': '00693U',
#   'Name': '期街口S&P黃豆',
#   'TradeVolume': '181700',
#   'TradeValue': '3751930',
#   'OpeningPrice': '20.69',
#   'HighestPrice': '20.69',
#   'LowestPrice': '20.61',
#   'ClosingPrice': '20.68',
#   'Change': '-0.1600',
#   'Transaction': '78'},
#  {'Code': '00700',
#   'Name': '富邦恒生國企',
#   'TradeVolume': '217736',
#   'TradeValue': '2743515',
#   'OpeningPrice': '12.40',
#   'HighestPrice': '12.75',
#   'LowestPrice': '12.40',
#   'ClosingPrice': '12.72',
#   'Change': '0.3000',
#   'Transaction': '135'},
#  {'Code': '00701',
#   'Name': '國泰股利精選30',
#   'TradeVolume': '528935',
#   'TradeValue': '15270440',
#   'OpeningPrice': '28.63',
#   'HighestPrice': '28.98',
#   'LowestPrice': '28.63',
#   'ClosingPrice': '28.95',
#   'Change': '0.3400',
#   'Transaction': '482'},
#  {'Code': '00702',
#   'Name': '國泰標普低波高息',
#   'TradeVolume': '4725',
#   'TradeValue': '119457',
#   'OpeningPrice': '25.40',
#   'HighestPrice': '25.40',
#   'LowestPrice': '25.28',
#   'ClosingPrice': '25.28',
#   'Change': '0.1000',
#   'Transaction': '82'},
#  {'Code': '00703',
#   'Name': '台新MSCI中國',
#   'TradeVolume': '71241',
#   'TradeValue': '1059110',
#   'OpeningPrice': '14.65',
#   'HighestPrice': '15.05',
#   'LowestPrice': '14.65',
#   'ClosingPrice': '15.04',
#   'Change': '0.3900',
#   'Transaction': '85'},
#  {'Code': '00706L',
#   'Name': '期元大S&P日圓正2',
#   'TradeVolume': '29086440',
#   'TradeValue': '204512216',
#   'OpeningPrice': '7.04',
#   'HighestPrice': '7.11',
#   'LowestPrice': '6.98',
#   'ClosingPrice': '7.11',
#   'Change': '-0.1400',
#   'Transaction': '3252'},
#  {'Code': '00707R',
#   'Name': '期元大S&P日圓反1',
#   'TradeVolume': '3000',
#   'TradeValue': '82760',
#   'OpeningPrice': '27.55',
#   'HighestPrice': '27.61',
#   'LowestPrice': '27.55',
#   'ClosingPrice': '27.60',
#   'Change': '0.4000',
#   'Transaction': '3'},
#  {'Code': '00708L',
#   'Name': '期元大S&P黃金正2',
#   'TradeVolume': '1401789',
#   'TradeValue': '53951795',
#   'OpeningPrice': '38.46',
#   'HighestPrice': '38.84',
#   'LowestPrice': '38.33',
#   'ClosingPrice': '38.81',
#   'Change': '0.0200',
#   'Transaction': '375'},
#  {'Code': '00709',
#   'Name': '富邦歐洲',
#   'TradeVolume': '235513',
#   'TradeValue': '7152682',
#   'OpeningPrice': '30.39',
#   'HighestPrice': '30.43',
#   'LowestPrice': '30.34',
#   'ClosingPrice': '30.35',
#   'Change': '-0.0800',
#   'Transaction': '143'},
#  {'Code': '00710B',
#   'Name': '復華彭博非投等債',
#   'TradeVolume': '387878',
#   'TradeValue': '7572716',
#   'OpeningPrice': '19.54',
#   'HighestPrice': '19.57',
#   'LowestPrice': '19.50',
#   'ClosingPrice': '19.53',
#   'Change': '0.0000',
#   'Transaction': '112'},
#  {'Code': '00711B',
#   'Name': '復華彭博新興債',
#   'TradeVolume': '178022',
#   'TradeValue': '3060056',
#   'OpeningPrice': '17.21',
#   'HighestPrice': '17.21',
#   'LowestPrice': '17.16',
#   'ClosingPrice': '17.19',
#   'Change': '0.0000',
#   'Transaction': '96'},
#  {'Code': '00712',
#   'Name': '復華富時不動產',
#   'TradeVolume': '30970461',
#   'TradeValue': '312806164',
#   'OpeningPrice': '10.11',
#   'HighestPrice': '10.13',
#   'LowestPrice': '10.07',
#   'ClosingPrice': '10.11',
#   'Change': '0.0000',
#   'Transaction': '4079'},
#  {'Code': '00713',
#   'Name': '元大台灣高息低波',
#   'TradeVolume': '14779587',
#   'TradeValue': '839042793',
#   'OpeningPrice': '56.80',
#   'HighestPrice': '57.00',
#   'LowestPrice': '56.60',
#   'ClosingPrice': '56.65',
#   'Change': '-0.0500',
#   'Transaction': '14880'},
#  {'Code': '00714',
#   'Name': '群益道瓊美國地產',
#   'TradeVolume': '303659',
#   'TradeValue': '6857312',
#   'OpeningPrice': '22.55',
#   'HighestPrice': '22.60',
#   'LowestPrice': '22.55',
#   'ClosingPrice': '22.57',
#   'Change': '-0.0100',
#   'Transaction': '161'},
#  {'Code': '00715L',
#   'Name': '期街口布蘭特正2',
#   'TradeVolume': '52347472',
#   'TradeValue': '672104140',
#   'OpeningPrice': '12.80',
#   'HighestPrice': '12.94',
#   'LowestPrice': '12.68',
#   'ClosingPrice': '12.93',
#   'Change': '0.1600',
#   'Transaction': '4837'},
#  {'Code': '00717',
#   'Name': '富邦美國特別股',
#   'TradeVolume': '719442',
#   'TradeValue': '11884996',
#   'OpeningPrice': '16.42',
#   'HighestPrice': '16.55',
#   'LowestPrice': '16.42',
#   'ClosingPrice': '16.49',
#   'Change': '0.0700',
#   'Transaction': '249'},
#  {'Code': '00728',
#   'Name': '第一金工業30',
#   'TradeVolume': '185527',
#   'TradeValue': '5858614',
#   'OpeningPrice': '31.30',
#   'HighestPrice': '31.80',
#   'LowestPrice': '31.28',
#   'ClosingPrice': '31.80',
#   'Change': '0.5600',
#   'Transaction': '127'},
#  {'Code': '00730',
#   'Name': '富邦臺灣優質高息',
#   'TradeVolume': '645695',
#   'TradeValue': '14634404',
#   'OpeningPrice': '22.47',
#   'HighestPrice': '22.79',
#   'LowestPrice': '22.47',
#   'ClosingPrice': '22.68',
#   'Change': '0.2100',
#   'Transaction': '322'},
#  {'Code': '00731',
#   'Name': '復華富時高息低波',
#   'TradeVolume': '954097',
#   'TradeValue': '68301159',
#   'OpeningPrice': '71.50',
#   'HighestPrice': '71.90',
#   'LowestPrice': '71.40',
#   'ClosingPrice': '71.90',
#   'Change': '0.6000',
#   'Transaction': '487'},
#  {'Code': '00733',
#   'Name': '富邦臺灣中小',
#   'TradeVolume': '1214860',
#   'TradeValue': '66435457',
#   'OpeningPrice': '54.20',
#   'HighestPrice': '55.05',
#   'LowestPrice': '53.95',
#   'ClosingPrice': '54.90',
#   'Change': '0.7000',
#   'Transaction': '1033'},
#  {'Code': '00735',
#   'Name': '國泰臺韓科技',
#   'TradeVolume': '206297',
#   'TradeValue': '6603288',
#   'OpeningPrice': '31.87',
#   'HighestPrice': '32.16',
#   'LowestPrice': '31.77',
#   'ClosingPrice': '32.16',
#   'Change': '0.2100',
#   'Transaction': '213'},
#  {'Code': '00736',
#   'Name': '國泰新興市場',
#   'TradeVolume': '104902',
#   'TradeValue': '2433589',
#   'OpeningPrice': '23.15',
#   'HighestPrice': '23.23',
#   'LowestPrice': '23.15',
#   'ClosingPrice': '23.23',
#   'Change': '0.3300',
#   'Transaction': '107'},
#  {'Code': '00737',
#   'Name': '國泰AI+Robo',
#   'TradeVolume': '108620',
#   'TradeValue': '3227509',
#   'OpeningPrice': '29.61',
#   'HighestPrice': '29.80',
#   'LowestPrice': '29.61',
#   'ClosingPrice': '29.80',
#   'Change': '0.2600',
#   'Transaction': '120'},
#  {'Code': '00738U',
#   'Name': '期元大道瓊白銀',
#   'TradeVolume': '947818',
#   'TradeValue': '25729960',
#   'OpeningPrice': '27.06',
#   'HighestPrice': '27.50',
#   'LowestPrice': '26.88',
#   'ClosingPrice': '27.47',
#   'Change': '0.1300',
#   'Transaction': '335'},
#  {'Code': '00739',
#   'Name': '元大MSCI A股',
#   'TradeVolume': '56876',
#   'TradeValue': '1086421',
#   'OpeningPrice': '19.19',
#   'HighestPrice': '19.36',
#   'LowestPrice': '18.96',
#   'ClosingPrice': '19.28',
#   'Change': '0.2700',
#   'Transaction': '80'},
#  {'Code': '00752',
#   'Name': '中信中國50',
#   'TradeVolume': '3315935',
#   'TradeValue': '60043121',
#   'OpeningPrice': '17.80',
#   'HighestPrice': '18.27',
#   'LowestPrice': '17.79',
#   'ClosingPrice': '18.20',
#   'Change': '0.4000',
#   'Transaction': '745'},
#  {'Code': '00753L',
#   'Name': '中信中國50正2',
#   'TradeVolume': '22850842',
#   'TradeValue': '163432369',
#   'OpeningPrice': '6.98',
#   'HighestPrice': '7.30',
#   'LowestPrice': '6.93',
#   'ClosingPrice': '7.27',
#   'Change': '0.3600',
#   'Transaction': '2567'},
#  {'Code': '00757',
#   'Name': '統一FANG+',
#   'TradeVolume': '3097708',
#   'TradeValue': '266988776',
#   'OpeningPrice': '85.85',
#   'HighestPrice': '86.50',
#   'LowestPrice': '85.75',
#   'ClosingPrice': '86.40',
#   'Change': '1.2000',
#   'Transaction': '2233'},
#  {'Code': '00762',
#   'Name': '元大全球AI',
#   'TradeVolume': '276685',
#   'TradeValue': '16390808',
#   'OpeningPrice': '59.05',
#   'HighestPrice': '59.55',
#   'LowestPrice': '59.00',
#   'ClosingPrice': '59.50',
#   'Change': '0.4500',
#   'Transaction': '312'},
#  {'Code': '00763U',
#   'Name': '期街口道瓊銅',
#   'TradeVolume': '319576',
#   'TradeValue': '8242312',
#   'OpeningPrice': '25.79',
#   'HighestPrice': '26.01',
#   'LowestPrice': '25.69',
#   'ClosingPrice': '26.01',
#   'Change': '0.3100',
#   'Transaction': '102'},
#  {'Code': '00770',
#   'Name': '國泰北美科技',
#   'TradeVolume': '434987',
#   'TradeValue': '19878726',
#   'OpeningPrice': '45.52',
#   'HighestPrice': '45.89',
#   'LowestPrice': '45.51',
#   'ClosingPrice': '45.88',
#   'Change': '0.5200',
#   'Transaction': '318'},
#  {'Code': '00771',
#   'Name': '元大US高息特別股',
#   'TradeVolume': '8504',
#   'TradeValue': '152765',
#   'OpeningPrice': '17.99',
#   'HighestPrice': '18.00',
#   'LowestPrice': '17.96',
#   'ClosingPrice': '17.96',
#   'Change': '0.0100',
#   'Transaction': '91'},
#  {'Code': '00775B',
#   'Name': '新光投等債15+',
#   'TradeVolume': '864000',
#   'TradeValue': '31346780',
#   'OpeningPrice': '36.19',
#   'HighestPrice': '36.32',
#   'LowestPrice': '36.19',
#   'ClosingPrice': '36.25',
#   'Change': '-0.1800',
#   'Transaction': '65'},
#  {'Code': '00783',
#   'Name': '富邦中証500',
#   'TradeVolume': '111511',
#   'TradeValue': '1753702',
#   'OpeningPrice': '15.50',
#   'HighestPrice': '15.87',
#   'LowestPrice': '15.50',
#   'ClosingPrice': '15.83',
#   'Change': '0.4600',
#   'Transaction': '69'},
#  {'Code': '00830',
#   'Name': '國泰費城半導體',
#   'TradeVolume': '9654026',
#   'TradeValue': '428344666',
#   'OpeningPrice': '44.17',
#   'HighestPrice': '44.59',
#   'LowestPrice': '44.11',
#   'ClosingPrice': '44.55',
#   'Change': '0.4800',
#   'Transaction': '2218'},
#  {'Code': '00850',
#   'Name': '元大臺灣ESG永續',
#   'TradeVolume': '774860',
#   'TradeValue': '33620112',
#   'OpeningPrice': '42.94',
#   'HighestPrice': '43.65',
#   'LowestPrice': '42.94',
#   'ClosingPrice': '43.57',
#   'Change': '0.4900',
#   'Transaction': '914'},
#  {'Code': '00851',
#   'Name': '台新全球AI',
#   'TradeVolume': '9576',
#   'TradeValue': '437245',
#   'OpeningPrice': '45.60',
#   'HighestPrice': '45.88',
#   'LowestPrice': '45.60',
#   'ClosingPrice': '45.88',
#   'Change': '0.3700',
#   'Transaction': '60'},
#  {'Code': '00852L',
#   'Name': '國泰美國道瓊正2',
#   'TradeVolume': '193180',
#   'TradeValue': '5079835',
#   'OpeningPrice': '26.22',
#   'HighestPrice': '26.36',
#   'LowestPrice': '26.17',
#   'ClosingPrice': '26.36',
#   'Change': '0.1600',
#   'Transaction': '51'},
#  {'Code': '00861',
#   'Name': '元大全球未來通訊',
#   'TradeVolume': '588663',
#   'TradeValue': '24300227',
#   'OpeningPrice': '41.22',
#   'HighestPrice': '41.36',
#   'LowestPrice': '41.22',
#   'ClosingPrice': '41.33',
#   'Change': '0.1100',
#   'Transaction': '156'},
#  {'Code': '00865B',
#   'Name': '國泰US短期公債',
#   'TradeVolume': '117864',
#   'TradeValue': '5356565',
#   'OpeningPrice': '45.40',
#   'HighestPrice': '45.51',
#   'LowestPrice': '45.40',
#   'ClosingPrice': '45.43',
#   'Change': '0.1100',
#   'Transaction': '102'},
#  {'Code': '00875',
#   'Name': '國泰網路資安',
#   'TradeVolume': '482551',
#   'TradeValue': '15871828',
#   'OpeningPrice': '32.73',
#   'HighestPrice': '33.00',
#   'LowestPrice': '32.73',
#   'ClosingPrice': '32.98',
#   'Change': '0.2100',
#   'Transaction': '110'},
#  {'Code': '00876',
#   'Name': '元大全球5G',
#   'TradeVolume': '124126',
#   'TradeValue': '4515661',
#   'OpeningPrice': '36.43',
#   'HighestPrice': '36.53',
#   'LowestPrice': '36.18',
#   'ClosingPrice': '36.50',
#   'Change': '0.2800',
#   'Transaction': '161'},
#  {'Code': '00878',
#   'Name': '國泰永續高股息',
#   'TradeVolume': '24107291',
#   'TradeValue': '537442242',
#   'OpeningPrice': '22.19',
#   'HighestPrice': '22.40',
#   'LowestPrice': '22.16',
#   'ClosingPrice': '22.32',
#   'Change': '0.1300',
#   'Transaction': '12653'},
#  {'Code': '00881',
#   'Name': '國泰台灣5G+',
#   'TradeVolume': '10782902',
#   'TradeValue': '242664198',
#   'OpeningPrice': '22.32',
#   'HighestPrice': '22.70',
#   'LowestPrice': '22.30',
#   'ClosingPrice': '22.67',
#   'Change': '0.3500',
#   'Transaction': '3114'},
#  {'Code': '00882',
#   'Name': '中信中國高股息',
#   'TradeVolume': '13719075',
#   'TradeValue': '148166081',
#   'OpeningPrice': '10.68',
#   'HighestPrice': '10.89',
#   'LowestPrice': '10.66',
#   'ClosingPrice': '10.89',
#   'Change': '0.2200',
#   'Transaction': '2447'},
#  {'Code': '00885',
#   'Name': '富邦越南',
#   'TradeVolume': '3441414',
#   'TradeValue': '41441389',
#   'OpeningPrice': '12.03',
#   'HighestPrice': '12.06',
#   'LowestPrice': '12.01',
#   'ClosingPrice': '12.02',
#   'Change': '-0.0300',
#   'Transaction': '774'},
#  {'Code': '00891',
#   'Name': '中信關鍵半導體',
#   'TradeVolume': '3294701',
#   'TradeValue': '57351110',
#   'OpeningPrice': '17.35',
#   'HighestPrice': '17.58',
#   'LowestPrice': '17.26',
#   'ClosingPrice': '17.58',
#   'Change': '0.2300',
#   'Transaction': '1570'},
#  {'Code': '00892',
#   'Name': '富邦台灣半導體',
#   'TradeVolume': '1511601',
#   'TradeValue': '24533360',
#   'OpeningPrice': '16.12',
#   'HighestPrice': '16.39',
#   'LowestPrice': '16.09',
#   'ClosingPrice': '16.39',
#   'Change': '0.2700',
#   'Transaction': '591'},
#  {'Code': '00893',
#   'Name': '國泰智能電動車',
#   'TradeVolume': '6625862',
#   'TradeValue': '142195025',
#   'OpeningPrice': '21.29',
#   'HighestPrice': '21.51',
#   'LowestPrice': '21.29',
#   'ClosingPrice': '21.48',
#   'Change': '0.1900',
#   'Transaction': '806'},
#  {'Code': '00894',
#   'Name': '中信小資高價30',
#   'TradeVolume': '580077',
#   'TradeValue': '11349959',
#   'OpeningPrice': '19.45',
#   'HighestPrice': '19.83',
#   'LowestPrice': '19.36',
#   'ClosingPrice': '19.81',
#   'Change': '0.4700',
#   'Transaction': '256'},
#  {'Code': '00895',
#   'Name': '富邦未來車',
#   'TradeVolume': '2582964',
#   'TradeValue': '70977969',
#   'OpeningPrice': '27.21',
#   'HighestPrice': '27.64',
#   'LowestPrice': '27.21',
#   'ClosingPrice': '27.63',
#   'Change': '0.4200',
#   'Transaction': '1079'},
#  {'Code': '00896',
#   'Name': '中信綠能及電動車',
#   'TradeVolume': '518923',
#   'TradeValue': '8843414',
#   'OpeningPrice': '16.96',
#   'HighestPrice': '17.17',
#   'LowestPrice': '16.92',
#   'ClosingPrice': '17.16',
#   'Change': '0.2100',
#   'Transaction': '320'},
#  {'Code': '00897',
#   'Name': '富邦基因免疫生技',
#   'TradeVolume': '1090533',
#   'TradeValue': '9243455',
#   'OpeningPrice': '8.44',
#   'HighestPrice': '8.50',
#   'LowestPrice': '8.44',
#   'ClosingPrice': '8.48',
#   'Change': '0.0400',
#   'Transaction': '187'},
#  {'Code': '00898',
#   'Name': '國泰基因免疫革命',
#   'TradeVolume': '443913',
#   'TradeValue': '3408699',
#   'OpeningPrice': '7.65',
#   'HighestPrice': '7.70',
#   'LowestPrice': '7.65',
#   'ClosingPrice': '7.68',
#   'Change': '0.0300',
#   'Transaction': '168'},
#  {'Code': '00899',
#   'Name': 'FT潔淨能源',
#   'TradeVolume': '45718',
#   'TradeValue': '761545',
#   'OpeningPrice': '16.66',
#   'HighestPrice': '16.68',
#   'LowestPrice': '16.61',
#   'ClosingPrice': '16.67',
#   'Change': '0.1200',
#   'Transaction': '88'},
#  {'Code': '00900',
#   'Name': '富邦特選高股息30',
#   'TradeVolume': '4857139',
#   'TradeValue': '71935543',
#   'OpeningPrice': '14.71',
#   'HighestPrice': '14.89',
#   'LowestPrice': '14.70',
#   'ClosingPrice': '14.84',
#   'Change': '0.1400',
#   'Transaction': '1670'},
#  {'Code': '00901',
#   'Name': '永豐智能車供應鏈',
#   'TradeVolume': '368559',
#   'TradeValue': '7279669',
#   'OpeningPrice': '19.64',
#   'HighestPrice': '19.93',
#   'LowestPrice': '19.58',
#   'ClosingPrice': '19.91',
#   'Change': '0.3300',
#   'Transaction': '167'},
#  {'Code': '00902',
#   'Name': '中信電池及儲能',
#   'TradeVolume': '2644846',
#   'TradeValue': '23409066',
#   'OpeningPrice': '8.84',
#   'HighestPrice': '8.90',
#   'LowestPrice': '8.80',
#   'ClosingPrice': '8.89',
#   'Change': '0.0500',
#   'Transaction': '328'},
#  {'Code': '00903',
#   'Name': '富邦元宇宙',
#   'TradeVolume': '519403',
#   'TradeValue': '7132203',
#   'OpeningPrice': '13.67',
#   'HighestPrice': '13.79',
#   'LowestPrice': '13.67',
#   'ClosingPrice': '13.76',
#   'Change': '0.0900',
#   'Transaction': '133'},
#  {'Code': '00904',
#   'Name': '新光臺灣半導體30',
#   'TradeVolume': '705213',
#   'TradeValue': '12103407',
#   'OpeningPrice': '17.08',
#   'HighestPrice': '17.33',
#   'LowestPrice': '17.00',
#   'ClosingPrice': '17.33',
#   'Change': '0.2800',
#   'Transaction': '265'},
#  {'Code': '00905',
#   'Name': 'FT臺灣Smart',
#   'TradeVolume': '1907876',
#   'TradeValue': '25244498',
#   'OpeningPrice': '13.15',
#   'HighestPrice': '13.30',
#   'LowestPrice': '13.11',
#   'ClosingPrice': '13.28',
#   'Change': '0.1900',
#   'Transaction': '993'},
#  {'Code': '00907',
#   'Name': '永豐優息存股',
#   'TradeVolume': '1863950',
#   'TradeValue': '29403077',
#   'OpeningPrice': '15.71',
#   'HighestPrice': '15.85',
#   'LowestPrice': '15.67',
#   'ClosingPrice': '15.84',
#   'Change': '0.1900',
#   'Transaction': '774'},
#  {'Code': '00908',
#   'Name': '富邦入息REITs+',
#   'TradeVolume': '554301',
#   'TradeValue': '7744511',
#   'OpeningPrice': '13.98',
#   'HighestPrice': '13.99',
#   'LowestPrice': '13.94',
#   'ClosingPrice': '13.99',
#   'Change': '0.0200',
#   'Transaction': '94'},
#  {'Code': '00909',
#   'Name': '國泰數位支付服務',
#   'TradeVolume': '1597186',
#   'TradeValue': '42206089',
#   'OpeningPrice': '26.09',
#   'HighestPrice': '26.49',
#   'LowestPrice': '26.09',
#   'ClosingPrice': '26.46',
#   'Change': '0.4100',
#   'Transaction': '810'},
#  {'Code': '00910',
#   'Name': '第一金太空衛星',
#   'TradeVolume': '227079',
#   'TradeValue': '5157245',
#   'OpeningPrice': '22.62',
#   'HighestPrice': '22.75',
#   'LowestPrice': '22.62',
#   'ClosingPrice': '22.72',
#   'Change': '0.1000',
#   'Transaction': '34'},
#  {'Code': '00911',
#   'Name': '兆豐洲際半導體',
#   'TradeVolume': '201588',
#   'TradeValue': '5159949',
#   'OpeningPrice': '25.45',
#   'HighestPrice': '25.69',
#   'LowestPrice': '25.45',
#   'ClosingPrice': '25.63',
#   'Change': '0.1800',
#   'Transaction': '154'},
#  {'Code': '00912',
#   'Name': '中信臺灣智慧50',
#   'TradeVolume': '67871',
#   'TradeValue': '1266712',
#   'OpeningPrice': '18.52',
#   'HighestPrice': '18.80',
#   'LowestPrice': '18.52',
#   'ClosingPrice': '18.80',
#   'Change': '0.3200',
#   'Transaction': '129'},
#  {'Code': '00913',
#   'Name': '兆豐台灣晶圓製造',
#   'TradeVolume': '152411',
#   'TradeValue': '3086995',
#   'OpeningPrice': '20.12',
#   'HighestPrice': '20.41',
#   'LowestPrice': '20.08',
#   'ClosingPrice': '20.40',
#   'Change': '0.2800',
#   'Transaction': '47'},
#  {'Code': '00915',
#   'Name': '凱基優選高股息30',
#   'TradeVolume': '36378249',
#   'TradeValue': '963379511',
#   'OpeningPrice': '26.47',
#   'HighestPrice': '26.56',
#   'LowestPrice': '26.41',
#   'ClosingPrice': '26.45',
#   'Change': '0.0000',
#   'Transaction': '17971'},
#  {'Code': '00916',
#   'Name': '國泰全球品牌50',
#   'TradeVolume': '353633',
#   'TradeValue': '8048964',
#   'OpeningPrice': '22.61',
#   'HighestPrice': '22.84',
#   'LowestPrice': '22.61',
#   'ClosingPrice': '22.83',
#   'Change': '0.2200',
#   'Transaction': '378'},
#  {'Code': '00917',
#   'Name': '中信特選金融',
#   'TradeVolume': '278231',
#   'TradeValue': '5816237',
#   'OpeningPrice': '20.82',
#   'HighestPrice': '20.92',
#   'LowestPrice': '20.82',
#   'ClosingPrice': '20.91',
#   'Change': '0.0900',
#   'Transaction': '129'},
#  {'Code': '00918',
#   'Name': '大華優利高填息30',
#   'TradeVolume': '31269877',
#   'TradeValue': '739011361',
#   'OpeningPrice': '23.60',
#   'HighestPrice': '23.74',
#   'LowestPrice': '23.53',
#   'ClosingPrice': '23.65',
#   'Change': '0.0000',
#   'Transaction': '13375'},
#  {'Code': '00919',
#   'Name': '群益台灣精選高息',
#   'TradeVolume': '110598513',
#   'TradeValue': '2664645211',
#   'OpeningPrice': '24.00',
#   'HighestPrice': '24.18',
#   'LowestPrice': '24.00',
#   'ClosingPrice': '24.13',
#   'Change': '0.1100',
#   'Transaction': '29606'},
#  {'Code': '00920',
#   'Name': '富邦ESG綠色電力',
#   'TradeVolume': '308033',
#   'TradeValue': '4706888',
#   'OpeningPrice': '15.24',
#   'HighestPrice': '15.33',
#   'LowestPrice': '15.24',
#   'ClosingPrice': '15.32',
#   'Change': '0.1400',
#   'Transaction': '106'},
#  {'Code': '00921',
#   'Name': '兆豐龍頭等權重',
#   'TradeVolume': '5463826',
#   'TradeValue': '99238733',
#   'OpeningPrice': '18.14',
#   'HighestPrice': '18.32',
#   'LowestPrice': '18.10',
#   'ClosingPrice': '18.29',
#   'Change': '0.1500',
#   'Transaction': '1021'},
#  {'Code': '00922',
#   'Name': '國泰台灣領袖50',
#   'TradeVolume': '2954898',
#   'TradeValue': '62244946',
#   'OpeningPrice': '20.84',
#   'HighestPrice': '21.16',
#   'LowestPrice': '20.83',
#   'ClosingPrice': '21.16',
#   'Change': '0.3300',
#   'Transaction': '1109'},
#  {'Code': '00923',
#   'Name': '群益台ESG低碳50',
#   'TradeVolume': '3860882',
#   'TradeValue': '78711084',
#   'OpeningPrice': '20.29',
#   'HighestPrice': '20.54',
#   'LowestPrice': '20.25',
#   'ClosingPrice': '20.53',
#   'Change': '0.2400',
#   'Transaction': '1638'},
#  {'Code': '00924',
#   'Name': '復華S&P500成長',
#   'TradeVolume': '1251413',
#   'TradeValue': '28251078',
#   'OpeningPrice': '22.45',
#   'HighestPrice': '22.63',
#   'LowestPrice': '22.45',
#   'ClosingPrice': '22.61',
#   'Change': '0.1800',
#   'Transaction': '454'},
#  {'Code': '00925',
#   'Name': '新光標普電動車',
#   'TradeVolume': '265002',
#   'TradeValue': '4279800',
#   'OpeningPrice': '16.12',
#   'HighestPrice': '16.23',
#   'LowestPrice': '16.12',
#   'ClosingPrice': '16.23',
#   'Change': '0.1100',
#   'Transaction': '15'},
#  {'Code': '00926',
#   'Name': '凱基全球菁英55',
#   'TradeVolume': '96272',
#   'TradeValue': '2156720',
#   'OpeningPrice': '22.34',
#   'HighestPrice': '22.44',
#   'LowestPrice': '22.33',
#   'ClosingPrice': '22.42',
#   'Change': '0.0800',
#   'Transaction': '71'},
#  {'Code': '00927',
#   'Name': '群益半導體收益',
#   'TradeVolume': '4775414',
#   'TradeValue': '87822048',
#   'OpeningPrice': '18.29',
#   'HighestPrice': '18.49',
#   'LowestPrice': '18.25',
#   'ClosingPrice': '18.45',
#   'Change': '0.1600',
#   'Transaction': '1643'},
#  {'Code': '00929',
#   'Name': '復華台灣科技優息',
#   'TradeVolume': '103483916',
#   'TradeValue': '1947345597',
#   'OpeningPrice': '18.80',
#   'HighestPrice': '18.89',
#   'LowestPrice': '18.76',
#   'ClosingPrice': '18.82',
#   'Change': '0.0000',
#   'Transaction': '43665'},
#  {'Code': '00930',
#   'Name': '永豐ESG低碳高息',
#   'TradeVolume': '10018111',
#   'TradeValue': '190621898',
#   'OpeningPrice': '19.01',
#   'HighestPrice': '19.09',
#   'LowestPrice': '18.94',
#   'ClosingPrice': '19.06',
#   'Change': '0.0800',
#   'Transaction': '2205'},
#  {'Code': '00932',
#   'Name': '兆豐永續高息等權',
#   'TradeVolume': '2206606',
#   'TradeValue': '36404128',
#   'OpeningPrice': '16.43',
#   'HighestPrice': '16.57',
#   'LowestPrice': '16.41',
#   'ClosingPrice': '16.56',
#   'Change': '0.1400',
#   'Transaction': '746'},
#  {'Code': '00934',
#   'Name': '中信成長高股息',
#   'TradeVolume': '7544371',
#   'TradeValue': '142692611',
#   'OpeningPrice': '18.81',
#   'HighestPrice': '19.00',
#   'LowestPrice': '18.79',
#   'ClosingPrice': '18.96',
#   'Change': '0.1500',
#   'Transaction': '2347'},
#  {'Code': '00935',
#   'Name': '野村臺灣新科技50',
#   'TradeVolume': '4393288',
#   'TradeValue': '90953735',
#   'OpeningPrice': '20.61',
#   'HighestPrice': '20.88',
#   'LowestPrice': '20.50',
#   'ClosingPrice': '20.86',
#   'Change': '0.3200',
#   'Transaction': '2039'},
#  {'Code': '00936',
#   'Name': '台新永續高息中小',
#   'TradeVolume': '6320218',
#   'TradeValue': '103468324',
#   'OpeningPrice': '16.26',
#   'HighestPrice': '16.45',
#   'LowestPrice': '16.26',
#   'ClosingPrice': '16.37',
#   'Change': '0.1200',
#   'Transaction': '2071'},
#  {'Code': '00939',
#   'Name': '統一台灣高息動能',
#   'TradeVolume': '9146932',
#   'TradeValue': '132205266',
#   'OpeningPrice': '14.39',
#   'HighestPrice': '14.51',
#   'LowestPrice': '14.37',
#   'ClosingPrice': '14.46',
#   'Change': '0.0700',
#   'Transaction': '2367'},
#  {'Code': '00940',
#   'Name': '元大台灣價值高息',
#   'TradeVolume': '46267428',
#   'TradeValue': '440264121',
#   'OpeningPrice': '9.47',
#   'HighestPrice': '9.56',
#   'LowestPrice': '9.45',
#   'ClosingPrice': '9.53',
#   'Change': '0.0600',
#   'Transaction': '9787'},
#  {'Code': '00941',
#   'Name': '中信上游半導體',
#   'TradeVolume': '4917018',
#   'TradeValue': '69752420',
#   'OpeningPrice': '14.08',
#   'HighestPrice': '14.23',
#   'LowestPrice': '14.08',
#   'ClosingPrice': '14.23',
#   'Change': '0.1400',
#   'Transaction': '958'},
#  {'Code': '00943',
#   'Name': '兆豐電子高息等權',
#   'TradeVolume': '2094999',
#   'TradeValue': '30236938',
#   'OpeningPrice': '14.36',
#   'HighestPrice': '14.52',
#   'LowestPrice': '14.36',
#   'ClosingPrice': '14.51',
#   'Change': '0.1600',
#   'Transaction': '532'},
#  {'Code': '00944',
#   'Name': '野村趨勢動能高息',
#   'TradeVolume': '1578347',
#   'TradeValue': '23518572',
#   'OpeningPrice': '14.84',
#   'HighestPrice': '14.98',
#   'LowestPrice': '14.81',
#   'ClosingPrice': '14.92',
#   'Change': '0.1200',
#   'Transaction': '453'},
#  {'Code': '00945B',
#   'Name': '凱基美國非投等債',
#   'TradeVolume': '16465611',
#   'TradeValue': '249651884',
#   'OpeningPrice': '15.14',
#   'HighestPrice': '15.18',
#   'LowestPrice': '15.13',
#   'ClosingPrice': '15.16',
#   'Change': '0.0000',
#   'Transaction': '1693'},
#  {'Code': '00946',
#   'Name': '群益科技高息成長',
#   'TradeVolume': '11126972',
#   'TradeValue': '107297349',
#   'OpeningPrice': '9.63',
#   'HighestPrice': '9.68',
#   'LowestPrice': '9.59',
#   'ClosingPrice': '9.64',
#   'Change': '0.0200',
#   'Transaction': '2844'},
#  {'Code': '00947',
#   'Name': '台新臺灣IC設計',
#   'TradeVolume': '3087109',
#   'TradeValue': '41536796',
#   'OpeningPrice': '13.30',
#   'HighestPrice': '13.56',
#   'LowestPrice': '13.26',
#   'ClosingPrice': '13.56',
#   'Change': '0.3000',
#   'Transaction': '776'},
#  {'Code': '00949',
#   'Name': '復華日本龍頭',
#   'TradeVolume': '6961298',
#   'TradeValue': '104488855',
#   'OpeningPrice': '14.91',
#   'HighestPrice': '15.05',
#   'LowestPrice': '14.91',
#   'ClosingPrice': '15.05',
#   'Change': '0.3200',
#   'Transaction': '1038'},
#  {'Code': '00951',
#   'Name': '台新日本半導體',
#   'TradeVolume': '2607528',
#   'TradeValue': '21626125',
#   'OpeningPrice': '8.29',
#   'HighestPrice': '8.35',
#   'LowestPrice': '8.25',
#   'ClosingPrice': '8.35',
#   'Change': '0.1300',
#   'Transaction': '588'},
#  {'Code': '00952',
#   'Name': '凱基台灣AI50',
#   'TradeVolume': '7202282',
#   'TradeValue': '70893258',
#   'OpeningPrice': '9.76',
#   'HighestPrice': '9.89',
#   'LowestPrice': '9.75',
#   'ClosingPrice': '9.89',
#   'Change': '0.1400',
#   'Transaction': '1033'},
#  {'Code': '00953B',
#   'Name': '群益優選非投等債',
#   'TradeVolume': '35981784',
#   'TradeValue': '361373581',
#   'OpeningPrice': '10.02',
#   'HighestPrice': '10.06',
#   'LowestPrice': '10.02',
#   'ClosingPrice': '10.04',
#   'Change': '0.0300',
#   'Transaction': '1782'},
#  {'Code': '00954',
#   'Name': '中信日本半導體',
#   'TradeVolume': '1877867',
#   'TradeValue': '16387623',
#   'OpeningPrice': '8.68',
#   'HighestPrice': '8.80',
#   'LowestPrice': '8.67',
#   'ClosingPrice': '8.80',
#   'Change': '0.1400',
#   'Transaction': '326'},
#  {'Code': '00956',
#   'Name': '中信日經高股息',
#   'TradeVolume': '2418434',
#   'TradeValue': '23991465',
#   'OpeningPrice': '9.83',
#   'HighestPrice': '9.95',
#   'LowestPrice': '9.83',
#   'ClosingPrice': '9.93',
#   'Change': '0.1600',
#   'Transaction': '208'},
#  {'Code': '01001T',
#   'Name': '土銀富邦R1',
#   'TradeVolume': '32000',
#   'TradeValue': '442240',
#   'OpeningPrice': '13.82',
#   'HighestPrice': '13.82',
#   'LowestPrice': '13.82',
#   'ClosingPrice': '13.82',
#   'Change': '0.0100',
#   'Transaction': '6'},
#  {'Code': '01002T',
#   'Name': '土銀國泰R1',
#   'TradeVolume': '807000',
#   'TradeValue': '13395700',
#   'OpeningPrice': '16.60',
#   'HighestPrice': '16.60',
#   'LowestPrice': '16.55',
#   'ClosingPrice': '16.60',
#   'Change': '0.0000',
#   'Transaction': '147'},
#  {'Code': '01004T',
#   'Name': '土銀富邦R2',
#   'TradeVolume': '31000',
#   'TradeValue': '378990',
#   'OpeningPrice': '12.23',
#   'HighestPrice': '12.23',
#   'LowestPrice': '12.21',
#   'ClosingPrice': '12.22',
#   'Change': '0.0000',
#   'Transaction': '7'},
#  {'Code': '01007T',
#   'Name': '兆豐國泰R2',
#   'TradeVolume': '101002',
#   'TradeValue': '1646285',
#   'OpeningPrice': '16.25',
#   'HighestPrice': '16.30',
#   'LowestPrice': '16.25',
#   'ClosingPrice': '16.30',
#   'Change': '0.0000',
#   'Transaction': '4'},
#  {'Code': '01009T',
#   'Name': '王道圓滿R1',
#   'TradeVolume': '16000',
#   'TradeValue': '119450',
#   'OpeningPrice': '7.47',
#   'HighestPrice': '7.47',
#   'LowestPrice': '7.46',
#   'ClosingPrice': '7.47',
#   'Change': '0.0000',
#   'Transaction': '7'},
#  {'Code': '01010T',
#   'Name': '京城樂富R1',
#   'TradeVolume': '46320',
#   'TradeValue': '463059',
#   'OpeningPrice': '10.00',
#   'HighestPrice': '10.01',
#   'LowestPrice': '9.99',
#   'ClosingPrice': '10.01',
#   'Change': '0.0000',
#   'Transaction': '17'},
#  {'Code': '020000',
#   'Name': '富邦特選蘋果N',
#   'TradeVolume': '46000',
#   'TradeValue': '535260',
#   'OpeningPrice': '11.49',
#   'HighestPrice': '11.67',
#   'LowestPrice': '11.49',
#   'ClosingPrice': '11.67',
#   'Change': '0.2100',
#   'Transaction': '5'},
#  {'Code': '020011',
#   'Name': '統一微波高息20N',
#   'TradeVolume': '2000',
#   'TradeValue': '20160',
#   'OpeningPrice': '10.08',
#   'HighestPrice': '10.08',
#   'LowestPrice': '10.08',
#   'ClosingPrice': '10.08',
#   'Change': '-0.0100',
#   'Transaction': '1'},
#  {'Code': '020012',
#   'Name': '富邦行動通訊N',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '020015',
#   'Name': '統一MSCI美低波N',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '020016',
#   'Name': '統一MSCI美科技N',
#   'TradeVolume': '1000',
#   'TradeValue': '29000',
#   'OpeningPrice': '29.00',
#   'HighestPrice': '29.00',
#   'LowestPrice': '29.00',
#   'ClosingPrice': '29.00',
#   'Change': '0.0000',
#   'Transaction': '1'},
#  {'Code': '020018',
#   'Name': '統一價值成長30N',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '020019',
#   'Name': '統一特選台灣5GN',
#   'TradeVolume': '',
#   'TradeValue': '',
#   'OpeningPrice': '',
#   'HighestPrice': '',
#   'LowestPrice': '',
#   'ClosingPrice': '',
#   'Change': '0.0000',
#   'Transaction': ''},
#  {'Code': '02001L',
#   'Name': '富邦蘋果正二N',
#   'TradeVolume': '56000',
#   'TradeValue': '1376860',
#   'OpeningPrice': '24.25',
#   'HighestPrice': '24.87',
#   'LowestPrice': '24.14',
#   'ClosingPrice': '24.87',
#   'Change': '0.7200',
#   'Transaction': '13'},
#  {'Code': '02001R',
#   'Name': '富邦蘋果反一N',
#   'TradeVolume': '16000',
#   'TradeValue': '24000',
#   'OpeningPrice': '1.50',
#   'HighestPrice': '1.50',
#   'LowestPrice': '1.50',
#   'ClosingPrice': '1.50',
#   'Change': '0.0100',
#   'Transaction': '1'},
#  {'Code': '02001S',
#   'Name': '策元大加權策略N',
#   'TradeVolume': '6000',
#   'TradeValue': '43160',
#   'OpeningPrice': '7.19',
#   'HighestPrice': '7.21',
#   'LowestPrice': '7.19',
#   'ClosingPrice': '7.21',
#   'Change': '0.0000',
#   'Transaction': '2'},
#  {'Code': '020020',
#   'Name': '元大台股領航N',
#   'TradeVolume': '95000',
#   'TradeValue': '1058190',
#   'OpeningPrice': '10.98',
#   'HighestPrice': '11.20',
#   'LowestPrice': '10.98',
#   'ClosingPrice': '11.19',
#   'Change': '0.2400',
#   'Transaction': '16'},
#  {'Code': '020028',
#   'Name': '元大特選電動車N',
#   'TradeVolume': '10000',
#   'TradeValue': '91520',
#   'OpeningPrice': '9.09',
#   'HighestPrice': '9.19',
#   'LowestPrice': '9.09',
#   'ClosingPrice': '9.19',
#   'Change': '0.0500',
#   'Transaction': '5'},
#  {'Code': '020029',
#   'Name': '元大ESG高股息N',
#   'TradeVolume': '31000',
#   'TradeValue': '269540',
#   'OpeningPrice': '8.70',
#   'HighestPrice': '8.74',
#   'LowestPrice': '8.67',
#   'ClosingPrice': '8.74',
#   'Change': '0.0700',
#   'Transaction': '9'},
#  {'Code': '020030',
#   'Name': '統一智慧電動車N',
#   'TradeVolume': '56000',
#   'TradeValue': '337470',
#   'OpeningPrice': '5.91',
#   'HighestPrice': '6.03',
#   'LowestPrice': '5.91',
#   'ClosingPrice': '6.03',
#   'Change': '0.1200',
#   'Transaction': '7'},
#  {'Code': '020031',
#   'Name': '統一IC設計臺灣N',
#   'TradeVolume': '18000',
#   'TradeValue': '97190',
#   'OpeningPrice': '5.40',
#   'HighestPrice': '5.40',
#   'LowestPrice': '5.39',
#   'ClosingPrice': '5.40',
#   'Change': '0.0800',
#   'Transaction': '3'},
#  {'Code': '020032',
#   'Name': '元大綠能N',
#   'TradeVolume': '5000',
#   'TradeValue': '30400',
#   'OpeningPrice': '6.05',
# ...
#   'Change': '2.5000',
#   'Transaction': '4067'},
#  {'Code': '4960',
#   'Name': '誠美材',
#   'TradeVolume': '959330',
#   'TradeValue': '12964935',
#   'OpeningPrice': '13.50',
#   'HighestPrice': '13.60',
#   'LowestPrice': '13.40',
#   'ClosingPrice': '13.60',
#   'Change': '0.1500',
#   'Transaction': '409'},
#  {'Code': '4961',
#   'Name': '天鈺',
#   'TradeVolume': '940694',
#   'TradeValue': '240407106',
#   'OpeningPrice': '252.50',
#   'HighestPrice': '258.00',
#   'LowestPrice': '251.50',
#   'ClosingPrice': '255.00',
#   'Change': '5.0000',
#   'Transaction': '1051'},
#  {'Code': '4967',
#   'Name': '十銓',
#   'TradeVolume': '2070709',
#   'TradeValue': '212109382',
#   'OpeningPrice': '102.50',
#   'HighestPrice': '103.50',
#   'LowestPrice': '101.00',
#   'ClosingPrice': '103.00',
#   'Change': '0.5000',
#   'Transaction': '1727'},
#  {'Code': '4968',
#   'Name': '立積',
#   'TradeVolume': '2047643',
#   'TradeValue': '365365085',
#   'OpeningPrice': '174.50',
#   'HighestPrice': '182.00',
#   'LowestPrice': '174.00',
#   'ClosingPrice': '178.50',
#   'Change': '3.0000',
#   'Transaction': '3054'},
#  {'Code': '4976',
#   'Name': '佳凌',
#   'TradeVolume': '229183',
#   'TradeValue': '10029883',
#   'OpeningPrice': '43.80',
#   'HighestPrice': '44.25',
#   'LowestPrice': '43.10',
#   'ClosingPrice': '44.25',
#   'Change': '1.1500',
#   'Transaction': '197'},
#  {'Code': '4977',
#   'Name': '眾達-KY',
#   'TradeVolume': '23713332',
#   'TradeValue': '2610736668',
#   'OpeningPrice': '107.50',
#   'HighestPrice': '115.00',
#   'LowestPrice': '103.00',
#   'ClosingPrice': '112.50',
#   'Change': '6.5000',
#   'Transaction': '15776'},
#  {'Code': '4989',
#   'Name': '榮科',
#   'TradeVolume': '857848',
#   'TradeValue': '19103153',
#   'OpeningPrice': '20.80',
#   'HighestPrice': '22.60',
#   'LowestPrice': '20.70',
#   'ClosingPrice': '22.60',
#   'Change': '2.0500',
#   'Transaction': '488'},
#  {'Code': '4994',
#   'Name': '傳奇',
#   'TradeVolume': '79567',
#   'TradeValue': '9278775',
#   'OpeningPrice': '115.00',
#   'HighestPrice': '118.00',
#   'LowestPrice': '114.50',
#   'ClosingPrice': '117.50',
#   'Change': '3.0000',
#   'Transaction': '367'},
#  {'Code': '4999',
#   'Name': '鑫禾',
#   'TradeVolume': '38643',
#   'TradeValue': '1292691',
#   'OpeningPrice': '33.55',
#   'HighestPrice': '33.55',
#   'LowestPrice': '33.40',
#   'ClosingPrice': '33.50',
#   'Change': '0.1500',
#   'Transaction': '81'},
#  {'Code': '5007',
#   'Name': '三星',
#   'TradeVolume': '44239',
#   'TradeValue': '2489167',
#   'OpeningPrice': '56.30',
#   'HighestPrice': '56.40',
#   'LowestPrice': '56.00',
#   'ClosingPrice': '56.30',
#   'Change': '0.2000',
#   'Transaction': '45'},
#  {'Code': '5203',
#   'Name': '訊連',
#   'TradeVolume': '84955',
#   'TradeValue': '7746246',
#   'OpeningPrice': '90.60',
#   'HighestPrice': '92.00',
#   'LowestPrice': '90.60',
#   'ClosingPrice': '92.00',
#   'Change': '1.1000',
#   'Transaction': '88'},
#  {'Code': '5215',
#   'Name': '科嘉-KY',
#   'TradeVolume': '40050',
#   'TradeValue': '1917200',
#   'OpeningPrice': '47.70',
#   'HighestPrice': '48.20',
#   'LowestPrice': '47.55',
#   'ClosingPrice': '47.80',
#   'Change': '0.2000',
#   'Transaction': '43'},
#  {'Code': '5222',
#   'Name': '全訊',
#   'TradeVolume': '226972',
#   'TradeValue': '31875361',
#   'OpeningPrice': '140.50',
#   'HighestPrice': '141.50',
#   'LowestPrice': '139.50',
#   'ClosingPrice': '141.50',
#   'Change': '2.0000',
#   'Transaction': '363'},
#  {'Code': '5225',
#   'Name': '東科-KY',
#   'TradeVolume': '1012078',
#   'TradeValue': '140302847',
#   'OpeningPrice': '139.00',
#   'HighestPrice': '140.00',
#   'LowestPrice': '137.50',
#   'ClosingPrice': '139.50',
#   'Change': '1.5000',
#   'Transaction': '856'},
#  {'Code': '5234',
#   'Name': '達興材料',
#   'TradeVolume': '22945576',
#   'TradeValue': '5715700036',
#   'OpeningPrice': '259.00',
#   'HighestPrice': '267.00',
#   'LowestPrice': '233.50',
#   'ClosingPrice': '244.00',
#   'Change': '-4.5000',
#   'Transaction': '17280'},
#  {'Code': '5243',
#   'Name': '乙盛-KY',
#   'TradeVolume': '1334107',
#   'TradeValue': '81798417',
#   'OpeningPrice': '61.20',
#   'HighestPrice': '62.00',
#   'LowestPrice': '60.60',
#   'ClosingPrice': '62.00',
#   'Change': '1.0000',
#   'Transaction': '999'},
#  {'Code': '5244',
#   'Name': '弘凱',
#   'TradeVolume': '57101',
#   'TradeValue': '2564398',
#   'OpeningPrice': '44.95',
#   'HighestPrice': '45.50',
#   'LowestPrice': '44.30',
#   'ClosingPrice': '45.05',
#   'Change': '0.1000',
#   'Transaction': '54'},
#  {'Code': '5258',
#   'Name': '虹堡',
#   'TradeVolume': '372105',
#   'TradeValue': '48080845',
#   'OpeningPrice': '130.50',
#   'HighestPrice': '130.50',
#   'LowestPrice': '128.50',
#   'ClosingPrice': '129.50',
#   'Change': '0.5000',
#   'Transaction': '381'},
#  {'Code': '5269',
#   'Name': '祥碩',
#   'TradeVolume': '397860',
#   'TradeValue': '608786175',
#   'OpeningPrice': '1500.00',
#   'HighestPrice': '1560.00',
#   'LowestPrice': '1480.00',
#   'ClosingPrice': '1550.00',
#   'Change': '75.0000',
#   'Transaction': '891'},
#  {'Code': '5283',
#   'Name': '禾聯碩',
#   'TradeVolume': '105335',
#   'TradeValue': '10679140',
#   'OpeningPrice': '101.00',
#   'HighestPrice': '102.00',
#   'LowestPrice': '101.00',
#   'ClosingPrice': '101.50',
#   'Change': '0.0000',
#   'Transaction': '166'},
#  {'Code': '5284',
#   'Name': 'jpp-KY',
#   'TradeVolume': '297136',
#   'TradeValue': '36338670',
#   'OpeningPrice': '124.50',
#   'HighestPrice': '124.50',
#   'LowestPrice': '121.00',
#   'ClosingPrice': '122.00',
#   'Change': '-1.0000',
#   'Transaction': '235'},
#  {'Code': '5285',
#   'Name': '界霖',
#   'TradeVolume': '183227',
#   'TradeValue': '11895628',
#   'OpeningPrice': '64.80',
#   'HighestPrice': '65.40',
#   'LowestPrice': '63.60',
#   'ClosingPrice': '65.00',
#   'Change': '0.6000',
#   'Transaction': '156'},
#  {'Code': '5288',
#   'Name': '豐祥-KY',
#   'TradeVolume': '20000',
#   'TradeValue': '3855500',
#   'OpeningPrice': '192.00',
#   'HighestPrice': '194.00',
#   'LowestPrice': '192.00',
#   'ClosingPrice': '192.50',
#   'Change': '1.5000',
#   'Transaction': '16'},
#  {'Code': '5292',
#   'Name': '華懋',
#   'TradeVolume': '79886',
#   'TradeValue': '11979899',
#   'OpeningPrice': '150.50',
#   'HighestPrice': '151.00',
#   'LowestPrice': '148.50',
#   'ClosingPrice': '151.00',
#   'Change': '2.0000',
#   'Transaction': '317'},
#  {'Code': '5306',
#   'Name': '桂盟',
#   'TradeVolume': '198165',
#   'TradeValue': '29854859',
#   'OpeningPrice': '147.50',
#   'HighestPrice': '152.00',
#   'LowestPrice': '147.50',
#   'ClosingPrice': '151.50',
#   'Change': '4.5000',
#   'Transaction': '262'},
#  {'Code': '5388',
#   'Name': '中磊',
#   'TradeVolume': '2275925',
#   'TradeValue': '240195209',
#   'OpeningPrice': '104.00',
#   'HighestPrice': '107.00',
#   'LowestPrice': '104.00',
#   'ClosingPrice': '105.00',
#   'Change': '2.5000',
#   'Transaction': '1498'},
#  {'Code': '5434',
#   'Name': '崇越',
#   'TradeVolume': '678492',
#   'TradeValue': '188814148',
#   'OpeningPrice': '278.00',
#   'HighestPrice': '280.00',
#   'LowestPrice': '275.50',
#   'ClosingPrice': '279.50',
#   'Change': '2.5000',
#   'Transaction': '789'},
#  {'Code': '5469',
#   'Name': '瀚宇博',
#   'TradeVolume': '1731663',
#   'TradeValue': '91066423',
#   'OpeningPrice': '52.20',
#   'HighestPrice': '52.90',
#   'LowestPrice': '52.20',
#   'ClosingPrice': '52.80',
#   'Change': '0.9000',
#   'Transaction': '1354'},
#  {'Code': '5471',
#   'Name': '松翰',
#   'TradeVolume': '163880',
#   'TradeValue': '7119451',
#   'OpeningPrice': '43.40',
#   'HighestPrice': '43.80',
#   'LowestPrice': '43.10',
#   'ClosingPrice': '43.35',
#   'Change': '0.0000',
#   'Transaction': '155'},
#  {'Code': '5484',
#   'Name': '慧友',
#   'TradeVolume': '383272',
#   'TradeValue': '26910569',
#   'OpeningPrice': '70.00',
#   'HighestPrice': '71.20',
#   'LowestPrice': '69.30',
#   'ClosingPrice': '70.60',
#   'Change': '1.4000',
#   'Transaction': '527'},
#  {'Code': '5515',
#   'Name': '建國',
#   'TradeVolume': '621899',
#   'TradeValue': '14610321',
#   'OpeningPrice': '23.35',
#   'HighestPrice': '23.60',
#   'LowestPrice': '23.35',
#   'ClosingPrice': '23.60',
#   'Change': '0.4000',
#   'Transaction': '413'},
#  {'Code': '5519',
#   'Name': '隆大',
#   'TradeVolume': '1598572',
#   'TradeValue': '71717813',
#   'OpeningPrice': '43.75',
#   'HighestPrice': '45.45',
#   'LowestPrice': '43.75',
#   'ClosingPrice': '44.90',
#   'Change': '1.4000',
#   'Transaction': '1070'},
#  {'Code': '5521',
#   'Name': '工信',
#   'TradeVolume': '1410595',
#   'TradeValue': '16526399',
#   'OpeningPrice': '11.80',
#   'HighestPrice': '11.85',
#   'LowestPrice': '11.60',
#   'ClosingPrice': '11.75',
#   'Change': '0.0000',
#   'Transaction': '471'},
#  {'Code': '5522',
#   'Name': '遠雄',
#   'TradeVolume': '1467289',
#   'TradeValue': '114782555',
#   'OpeningPrice': '75.70',
#   'HighestPrice': '79.00',
#   'LowestPrice': '75.70',
#   'ClosingPrice': '79.00',
#   'Change': '3.0000',
#   'Transaction': '1347'},
#  {'Code': '5525',
#   'Name': '順天',
#   'TradeVolume': '123864',
#   'TradeValue': '4514423',
#   'OpeningPrice': '36.15',
#   'HighestPrice': '36.60',
#   'LowestPrice': '36.15',
#   'ClosingPrice': '36.55',
#   'Change': '0.5500',
#   'Transaction': '110'},
#  {'Code': '5531',
#   'Name': '鄉林',
#   'TradeVolume': '824826',
#   'TradeValue': '8513784',
#   'OpeningPrice': '10.25',
#   'HighestPrice': '10.40',
#   'LowestPrice': '10.25',
#   'ClosingPrice': '10.40',
#   'Change': '0.2000',
#   'Transaction': '393'},
#  {'Code': '5533',
#   'Name': '皇鼎',
#   'TradeVolume': '149001',
#   'TradeValue': '3309822',
#   'OpeningPrice': '22.25',
#   'HighestPrice': '22.30',
#   'LowestPrice': '22.10',
#   'ClosingPrice': '22.25',
#   'Change': '0.0000',
#   'Transaction': '88'},
#  {'Code': '5534',
#   'Name': '長虹',
#   'TradeVolume': '885157',
#   'TradeValue': '97092564',
#   'OpeningPrice': '107.00',
#   'HighestPrice': '111.00',
#   'LowestPrice': '107.00',
#   'ClosingPrice': '109.50',
#   'Change': '2.5000',
#   'Transaction': '789'},
#  {'Code': '5538',
#   'Name': '東明-KY',
#   'TradeVolume': '85606',
#   'TradeValue': '3262672',
#   'OpeningPrice': '38.30',
#   'HighestPrice': '38.50',
#   'LowestPrice': '37.65',
#   'ClosingPrice': '37.95',
#   'Change': '-0.4000',
#   'Transaction': '74'},
#  {'Code': '5546',
#   'Name': '永固-KY',
#   'TradeVolume': '8210',
#   'TradeValue': '241998',
#   'OpeningPrice': '29.60',
#   'HighestPrice': '29.60',
#   'LowestPrice': '29.40',
#   'ClosingPrice': '29.50',
#   'Change': '0.0500',
#   'Transaction': '10'},
#  {'Code': '5607',
#   'Name': '遠雄港',
#   'TradeVolume': '243808',
#   'TradeValue': '11431769',
#   'OpeningPrice': '47.25',
#   'HighestPrice': '47.25',
#   'LowestPrice': '46.45',
#   'ClosingPrice': '47.10',
#   'Change': '0.3500',
#   'Transaction': '321'},
#  {'Code': '5608',
#   'Name': '四維航',
#   'TradeVolume': '661348',
#   'TradeValue': '11496719',
#   'OpeningPrice': '17.40',
#   'HighestPrice': '17.50',
#   'LowestPrice': '17.25',
#   'ClosingPrice': '17.40',
#   'Change': '0.1000',
#   'Transaction': '469'},
#  {'Code': '5706',
#   'Name': '鳳凰',
#   'TradeVolume': '90866',
#   'TradeValue': '5315781',
#   'OpeningPrice': '58.00',
#   'HighestPrice': '58.80',
#   'LowestPrice': '58.00',
#   'ClosingPrice': '58.70',
#   'Change': '0.7000',
#   'Transaction': '117'},
#  {'Code': '5871',
#   'Name': '中租-KY',
#   'TradeVolume': '8530118',
#   'TradeValue': '1230710861',
#   'OpeningPrice': '142.50',
#   'HighestPrice': '145.50',
#   'LowestPrice': '142.00',
#   'ClosingPrice': '145.00',
#   'Change': '2.5000',
#   'Transaction': '4551'},
#  {'Code': '5871A',
#   'Name': '中租-KY甲特',
#   'TradeVolume': '25646',
#   'TradeValue': '2442010',
#   'OpeningPrice': '95.30',
#   'HighestPrice': '95.30',
#   'LowestPrice': '95.10',
#   'ClosingPrice': '95.20',
#   'Change': '0.0000',
#   'Transaction': '27'},
#  {'Code': '5876',
#   'Name': '上海商銀',
#   'TradeVolume': '8383377',
#   'TradeValue': '325693842',
#   'OpeningPrice': '38.50',
#   'HighestPrice': '39.45',
#   'LowestPrice': '38.30',
#   'ClosingPrice': '39.45',
#   'Change': '0.9500',
#   'Transaction': '3342'},
#  {'Code': '5880',
#   'Name': '合庫金',
#   'TradeVolume': '9036718',
#   'TradeValue': '232068687',
#   'OpeningPrice': '25.65',
#   'HighestPrice': '25.75',
#   'LowestPrice': '25.55',
#   'ClosingPrice': '25.65',
#   'Change': '0.0000',
#   'Transaction': '4671'},
#  {'Code': '5906',
#   'Name': '台南-KY',
#   'TradeVolume': '39554',
#   'TradeValue': '2259311',
#   'OpeningPrice': '57.50',
#   'HighestPrice': '58.40',
#   'LowestPrice': '55.50',
#   'ClosingPrice': '57.00',
#   'Change': '-0.5000',
#   'Transaction': '22'},
#  {'Code': '5907',
#   'Name': '大洋-KY',
#   'TradeVolume': '160150',
#   'TradeValue': '1357338',
#   'OpeningPrice': '8.48',
#   'HighestPrice': '8.55',
#   'LowestPrice': '8.40',
#   'ClosingPrice': '8.45',
#   'Change': '0.0000',
#   'Transaction': '80'},
#  {'Code': '6005',
#   'Name': '群益證',
#   'TradeVolume': '4813023',
#   'TradeValue': '100038807',
#   'OpeningPrice': '20.65',
#   'HighestPrice': '20.90',
#   'LowestPrice': '20.60',
#   'ClosingPrice': '20.90',
#   'Change': '0.3500',
#   'Transaction': '2281'},
#  {'Code': '6024',
#   'Name': '群益期',
#   'TradeVolume': '214310',
#   'TradeValue': '12062272',
#   'OpeningPrice': '56.20',
#   'HighestPrice': '56.50',
#   'LowestPrice': '56.00',
#   'ClosingPrice': '56.50',
#   'Change': '0.3000',
#   'Transaction': '421'},
#  {'Code': '6108',
#   'Name': '競國',
#   'TradeVolume': '785379',
#   'TradeValue': '13303176',
#   'OpeningPrice': '16.90',
#   'HighestPrice': '17.15',
#   'LowestPrice': '16.75',
#   'ClosingPrice': '17.00',
#   'Change': '0.0000',
#   'Transaction': '520'},
#  {'Code': '6112',
#   'Name': '邁達特',
#   'TradeVolume': '240671',
#   'TradeValue': '11209637',
#   'OpeningPrice': '46.45',
#   'HighestPrice': '46.85',
#   'LowestPrice': '46.05',
#   'ClosingPrice': '46.85',
#   'Change': '0.7500',
#   'Transaction': '232'},
#  {'Code': '6115',
#   'Name': '鎰勝',
#   'TradeVolume': '76848',
#   'TradeValue': '4009573',
#   'OpeningPrice': '51.70',
#   'HighestPrice': '52.30',
#   'LowestPrice': '51.70',
#   'ClosingPrice': '52.30',
#   'Change': '0.3000',
#   'Transaction': '101'},
#  {'Code': '6116',
#   'Name': '彩晶',
#   'TradeVolume': '5543295',
#   'TradeValue': '51250249',
#   'OpeningPrice': '9.23',
#   'HighestPrice': '9.28',
#   'LowestPrice': '9.19',
#   'ClosingPrice': '9.27',
#   'Change': '0.0000',
#   'Transaction': '2154'},
#  {'Code': '6117',
#   'Name': '迎廣',
#   'TradeVolume': '3323075',
#   'TradeValue': '315811372',
#   'OpeningPrice': '90.40',
#   'HighestPrice': '98.30',
#   'LowestPrice': '90.40',
#   'ClosingPrice': '96.80',
#   'Change': '6.7000',
#   'Transaction': '2910'},
#  {'Code': '6120',
#   'Name': '達運',
#   'TradeVolume': '1012068',
#   'TradeValue': '14793970',
#   'OpeningPrice': '14.50',
#   'HighestPrice': '14.75',
#   'LowestPrice': '14.35',
#   'ClosingPrice': '14.70',
#   'Change': '0.2000',
#   'Transaction': '510'},
#  {'Code': '6128',
#   'Name': '上福',
#   'TradeVolume': '221361',
#   'TradeValue': '7806237',
#   'OpeningPrice': '35.10',
#   'HighestPrice': '35.70',
#   'LowestPrice': '34.95',
#   'ClosingPrice': '35.55',
#   'Change': '0.5000',
#   'Transaction': '186'},
#  {'Code': '6133',
#   'Name': '金橋',
#   'TradeVolume': '2419545',
#   'TradeValue': '55339566',
#   'OpeningPrice': '22.90',
#   'HighestPrice': '23.10',
#   'LowestPrice': '22.60',
#   'ClosingPrice': '23.00',
#   'Change': '0.4000',
#   'Transaction': '1363'},
#  {'Code': '6136',
#   'Name': '富爾特',
#   'TradeVolume': '160465',
#   'TradeValue': '3639148',
#   'OpeningPrice': '22.75',
#   'HighestPrice': '22.85',
#   'LowestPrice': '22.50',
#   'ClosingPrice': '22.70',
#   'Change': '-0.0500',
#   'Transaction': '105'},
#  {'Code': '6139',
#   'Name': '亞翔',
#   'TradeVolume': '1860042',
#   'TradeValue': '390418655',
#   'OpeningPrice': '210.00',
#   'HighestPrice': '212.00',
#   'LowestPrice': '207.50',
#   'ClosingPrice': '212.00',
#   'Change': '2.5000',
#   'Transaction': '3083'},
#  {'Code': '6141',
#   'Name': '柏承',
#   'TradeVolume': '70155',
#   'TradeValue': '988781',
#   'OpeningPrice': '14.15',
#   'HighestPrice': '14.20',
#   'LowestPrice': '14.00',
#   'ClosingPrice': '14.15',
#   'Change': '0.0500',
#   'Transaction': '53'},
#  {'Code': '6142',
#   'Name': '友勁',
#   'TradeVolume': '1104268',
#   'TradeValue': '12548770',
#   'OpeningPrice': '11.65',
#   'HighestPrice': '11.70',
#   'LowestPrice': '11.20',
#   'ClosingPrice': '11.35',
#   'Change': '-0.2500',
#   'Transaction': '466'},
#  {'Code': '6152',
#   'Name': '百一',
#   'TradeVolume': '2692515',
#   'TradeValue': '47438896',
#   'OpeningPrice': '17.65',
#   'HighestPrice': '17.95',
#   'LowestPrice': '17.40',
#   'ClosingPrice': '17.60',
#   'Change': '-0.0500',
#   'Transaction': '1460'},
#  {'Code': '6153',
#   'Name': '嘉聯益',
#   'TradeVolume': '1120827',
#   'TradeValue': '23751817',
#   'OpeningPrice': '21.40',
#   'HighestPrice': '21.50',
#   'LowestPrice': '21.00',
#   'ClosingPrice': '21.30',
#   'Change': '0.0500',
#   'Transaction': '819'},
#  ...]

# %%
# 引入pandas庫
import pandas as pd
# 將JSON數據轉換為DataFrame
df = pd.DataFrame(jsondata)
# 將"Code"列設置為索引
df.set_index("Code", inplace=True)
# 將空字符串替換為'0'
df.replace('', '0', inplace=True)
# 將除了"Name"列以外的所有列轉換為浮點數
df[df.columns.difference(['Name'])] = df[df.columns.difference(['Name'])].astype(float)
# 顯示DataFrame
df
# Out:
#           Name  TradeVolume    TradeValue  OpeningPrice  HighestPrice  \
# Code
# 0050    元大台灣50    8553792.0  1.532937e+09        178.00        180.20
# 0051   元大中型100      54240.0  4.334120e+06         79.05         80.60
# 0052      富邦科技     340371.0  5.942914e+07        172.85        175.95
# 0053      元大電子       6900.0  6.601550e+05         95.45         96.45
# 0055  元大MSCI金融     122249.0  3.532429e+06         28.65         28.99
# ...        ...          ...           ...           ...           ...
# 9944        新麗     191192.0  3.850114e+06         20.05         20.30
# 9945       潤泰新   15967686.0  7.788504e+08         47.70         49.25
# 9946      三發地產     470056.0  1.535243e+07         32.10         33.10
# 9955        佳龍    1686832.0  6.127470e+07         36.60         36.85
# 9958       世紀鋼   12039459.0  2.741637e+09        213.50        234.50
#
#       LowestPrice  ClosingPrice  Change  Transaction
# Code
# 0050       177.00        180.15    2.30      10740.0
# 0051        79.05         80.60    1.35        203.0
# 0052       172.50        175.95    2.75        854.0
# 0053        95.00         96.45    1.60        108.0
# 0055        28.62         28.99    0.38        246.0
# ...           ...           ...     ...          ...
# 9944        20.05         20.20    0.00        271.0
# 9945        47.70         49.25    1.80       8922.0
# 9946        32.10         33.00    0.85        372.0
# 9955        35.95         35.95   -0.50       1345.0
# 9958       213.50        234.50   21.00       8891.0
#
# [1254 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://tw.stock.yahoo.com/quote/2330'    # 台積電 Yahoo 股市網址
web = requests.get(url)                          # 取得網頁內容
soup = BeautifulSoup(web.text, "html.parser")    # 轉換內容
title = soup.select('.Fz\(24px\)')[0]             # 找到 h1 的內容
a = soup.select('.Fz\(32px\)')[0]     # 找到第一個 class 為 Fz(32px) 的內容，如果出現錯誤，可以使用 .Fz\(32px\) 轉義
b = soup.select('.Fz\(20px\)')[0]     # 找到第一個 class 為 Fz(20px) 的內容，如果出現錯誤，可以使用 .Fz\(20px\) 轉義
s = ''                              # 漲或跌的狀態
try:
    # 如果 main-0-QuoteHeader-Proxy id 的 div 裡有 C($c-trend-down) 的 class
    # 表示狀態為下跌
    if soup.select('#main-0-QuoteHeader-Proxy')[0].select('.C($c-trend-down)')[0]:
        s = '-'
except:
    try:
        # 如果 main-0-QuoteHeader-Proxy id 的 div 裡有 C($c-trend-up) 的 class
        # 表示狀態為上漲
        if soup.select('#main-0-QuoteHeader-Proxy')[0].select('.C($c-trend-up)')[0]:
            s = '+'
    except:
        # 如果都沒有包含，表示平盤
        s = '-'

print(f'{title.get_text()} : {a.get_text()} ( {s}{b.get_text()} )')   # 印出結果
# Out:
# 台積電 : 974 ( -14.00 )
